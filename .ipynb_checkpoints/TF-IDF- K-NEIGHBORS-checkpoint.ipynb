# %%
import pandas as pd
import numpy as np
import time
import re
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/danterangel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
str_replaces_list = [
    ['*',' '],
    ['.',' '],
    ['-',' '],
    ['-',' '],
    ['01 ',''],
    ['02 ',''],
    ['03 ',''],
    ['04 ',''],
    ['05 ',''],
    ['06 ',''],
    ['07 ',''],
    ['08 ',''],
    ['09 ',''],
    ['/', ' '],
    ['AMEX','American Express'],
    ['IRS','Internal Revenue Service'],
    ['SYNCB','SYNCHRONY'],
    ['JPMCB - CARD SERVICE','JPMCB - CARD'],
    ['JPMCB','JPMChase Bank'],
    ['JPM CB','JPMChase Bank'],
    ['5TH 3RD','Fifth third'],
    ['5/3','Fifth third'],
    ['1NEVADACU','One Nevada'],
    ['CBNA','Citibank, N.A.'],
    ['TOYOTA MOTOR CREDIT','Toyota Financial Services'],
    ['ADVANT','Advantage'],
    ['CAPONE','Capital one'],
    ['CRED','Credit'],
    ['Ins ', 'Insurance '],
    ['P & C', 'Property & Casualty'],
    ['P&C', 'Property & Casualty'],
    ['P& C', 'Property & Casualty'],
    ['PROP & CAS', 'PROPERTY & CASUALTY'],
    ['INS ', 'INSURANCE '],
    ['CORP ', 'CORPORATE '],
    ['Ins. Co.', 'Insurance Companty'],
    ['Cas.', 'Casuality'],
    ['CAS UALTY', 'CASUALTY'],
    ['CAS CO', 'CASUALITY COMPANY'],
    ['COUNTRY INS', 'COMPANY INSURANCE'],
    ['FBSD','1st Financial Bank'],
    ['121FCU','Financial Credit Union'],
    ['121 FCU','Financial Credit Union'],
    ['1st Comm CU','first Community credit union'],
    ['1ST COMM','first Community'],
    ['1ST FEDERAL','first federal'],
    ['1ST FINANCIAL BANK ','first financial bank']
]
#str_replaces_list = []
b_words = [
    'insurance',
    'insurances',
    'bank',
    'counties',
    'credit',
    'finance',
    'financial',
    'services',
    'service',
    'credit',
    'service',
    'corporate',
    'company',
    'casuality',
    'exchange',
    'association',
    'cooperative',
    'property'
]

b_words = stopwords.words('english') + b_words

# %%
def str_replace(string, str_replaces_list):
    for i in str_replaces_list:
        string = string.replace(i[0], i[1])
    return string.lower()

# %%
def ngrams(string, n=12):
    string = string.encode("ascii", errors="ignore").decode() #remove non ascii chars
    string = string.lower() #make lower case
    string = str_replace(string,str_replaces_list)
    chars_to_remove = [")","(",".","|","[","]","{","}","'"]
    rx = '[' + re.escape(''.join(chars_to_remove)) + ']'
    string = re.sub(rx, '', string) #remove the list of chars defined above
    string = string.title() # normalise case - capital at start of each word
    string = re.sub(' +',' ',string).strip() # get rid of multiple spaces and replace with a single space
    string = ' '+ string +' ' # pad names for ngrams...
    string = re.sub(r'[,-./]|\sBD',r'', string)
    ngrams = zip(*[string[i:] for i in range(n)])
    return [''.join(ngram) for ngram in ngrams]

# %%
def train_vectorize(org_name_clean, unique_org,analyzer= 'char_wb'):
    t1 = time.time()
    print('=====================================================Vecorizing the data - this could take a few minutes for large datasets... =====================================================')
    vectorizer = TfidfVectorizer(min_df=1, analyzer=analyzer, stop_words=b_words)#, lowercase=False)
    tfidf = vectorizer.fit_transform(org_name_clean)
    t = time.time()-t1
    print("=====================  COMPLETED IN:", t)
    print('=====================  Vecorizing completed...')
    nbrs = NearestNeighbors(n_neighbors=NEIGHBORS, n_jobs=-1).fit(tfidf)
    query_tf_idf = vectorizer.transform(unique_org)
    distances, indices = nbrs.kneighbors(query_tf_idf)
    return distances, indices

# %%
def find_matches(matches,indices, distances, org_name_clean, unique_org, invert= True):
    
    t1 = time.time()
    print('=====================  finding matches...')
    for i,j in enumerate(indices):
        for k in range(0,len(j)):
            str1 = org_name_clean[j[k]].lower()
            str2 = unique_org[i].lower()
            similarity = fuzz.ratio(str1,str2)
            similarity_token_sort_ratio = fuzz.token_sort_ratio(str1,str2)
            if similarity > FILTER_SIMILARITY or similarity_token_sort_ratio > FILTER_SIMILARITY:
                if invert == True:
                    arcus_name = org_name_clean[j[k]]
                    quicken_name = unique_org[i]
                else:                    
                    arcus_name = unique_org[i]
                    quicken_name = org_name_clean[j[k]]
                temp = [round(distances[i][k],2), arcus_name , quicken_name, similarity, similarity_token_sort_ratio]
                matches.append(temp)

    t = time.time() - t1
    print("=====================  COMPLETED IN:", t)
    return matches

# %% [markdown]
# ## Files Names

# %%
file = "data_all.xlsx"
file_quicken = 'full_data_quicken.xlsx'
FILTER_SIMILARITY = 55
NEIGHBORS = 40
ANALIZERS = [
    'char_wb',
    'char',
    'word',
    ngrams
]

# %% [markdown]
# ## Get the Quicken Dataset

# %%
dataset = pd.read_excel(file_quicken, usecols=["Payable To"])
print(dataset.shape, 'dataset completo')
dataset = pd.DataFrame({'name': dataset['Payable To'].unique()})
dataset = dataset
print(dataset.shape, 'dataset con datos unicos')
# Out:
# (345610, 1) dataset completo
# (21109, 1) dataset con datos unicos

# %%
dataset.head(5)
# Out:
#                     name
# 0              SYNCB/PPC
# 1             CapitalOne
# 2              SYNCB/LOW
# 3         Goldenwest FCU
# 4  DISCOVER FIN SVCS LLC

# %% [markdown]
# ## Get Arcus Dataset

# %%
payees = pd.read_excel(file,sheet_name='USA-Full List')
payees.dropna(subset=['Name'], inplace=True)
payees['name'] = payees['Name']
payees.drop('Name', axis='columns', inplace=True)
print(payees.shape, " dataset arcus completo")
# Out:
# (16398, 2)  dataset arcus completo

# %%
payees.head(5)
# Out:
#        Category                         name
# 0       Airline            American Airlines
# 1       Airline           United Travel Card
# 2  Auto Finance         Ally Financial, Inc.
# 3  Auto Finance  American Honda Finance Corp
# 4  Auto Finance       BMW Financial Services

# %% [markdown]
# ## Copy Quicken Dataset and replace with our manual filter data and lower each string

# %%
dataset_client = dataset.copy()
dataset_client.name = dataset_client.apply(lambda row : str_replace(row['name'], str_replaces_list), axis = 1)
dataset_client = dataset_client.name

# %% [markdown]
# ## Copy Arcus Dataset and replace with our manual filter data and lower each string

# %%
dataset_payees = payees.copy()
dataset_payees.name = dataset_payees.apply(lambda row : str_replace(row['name'], str_replaces_list), axis = 1)
dataset_payees = dataset_payees.name

# %% [markdown]
# ### Match names Arcus vs Quicken with KNeighbors

# %%
clean_org_names = dataset_payees
org_name_clean = payees.name
matches = []
# Out:
# =====================  Match names Arcus vs Quicken with KNeighbors

# %%
print("=====================  Match names Arcus vs Quicken with KNeighbors")
t1 = time.time()
unique_org = dataset_client # set used for increased performance
for i in ANALIZERS:
    distances, indices = train_vectorize(org_name_clean, unique_org, analyzer=i)
    unique_org = dataset.name
    matches = matches + find_matches(matches,indices, distances, org_name_clean, unique_org)
t = time.time() - t1
print("=====================  COMPLETED IN:", t)
# Out:
# =====================================================Vecorizing the data - this could take a few minutes for large datasets... =====================================================
# =====================  COMPLETED IN: 0.37595605850219727
# =====================  Vecorizing completed...
# =====================  finding matches...
# =====================  COMPLETED IN: 25.936277151107788
# =====================================================Vecorizing the data - this could take a few minutes for large datasets... =====================================================
# =====================  COMPLETED IN: 0.15611886978149414
# =====================  Vecorizing completed...
# =====================  finding matches...
# =====================  COMPLETED IN: 35.40881276130676
# =====================================================Vecorizing the data - this could take a few minutes for large datasets... =====================================================
# =====================  COMPLETED IN: 0.1472761631011963
# =====================  Vecorizing completed...
# =====================  finding matches...
# =====================  COMPLETED IN: 26.562784910202026
# =====================================================Vecorizing the data - this could take a few minutes for large datasets... =====================================================
# =====================  COMPLETED IN: 0.9253079891204834
# =====================  Vecorizing completed...
# =====================  finding matches...
# =====================  COMPLETED IN: 18.501990795135498
# =====================  COMPLETED IN: 174.2350480556488

# %%
print('Building data frame...')  
matches_df = pd.DataFrame(matches, columns=['match confidence(knn)','Arcus name','Quicken name', 'similarity', 'similarity_token_sort_ratio'])
print('Done')
# Out:
# Building data frame...
# Done

# %%
matches_df.sample(20)
# Out:
#          match confidence(knn)                                     Arcus name  \
# 1202384                   1.00                        Service Finance Company
# 1018959                   0.56                             Village of Argenta
# 1274396                   0.32                     Southern California Edison
# 2329733                   0.83                           AAA Hawaii Insurance
# 139664                    0.42                         First Sentry Bank Loan
# 170152                    0.63                    Quality Water Solutions Inc
# 3189956                   0.43  Penn Treaty Network America Insurance Company
# 1445791                   0.38                      United American Insurance
# 2151271                   0.53                             Henry County Water
# 3106783                   0.41                            Russian Media Group
# 1567930                   0.46                         Pinnacle Bank Nebraska
# 2114956                   0.50                  The Highlands At Garthe Ranch
# 1344616                   0.39                               City Gas Company
# 2517956                   0.44                      Charter Township of Orion
# 72638                     0.14                          Guardian Credit Union
# 4758555                   0.52                        First Peoples Bank Loan
# 3505984                   0.29                                        SPC FCU
# 4617034                   0.40            Metropolitan Life Insurance Company
# 4600163                   0.48                American Modern Insurance Group
# 4692133                   0.46                           Aston Properties Inc
#
#                                               Quicken name  similarity  \
# 1202384                               Hawks View Insurance          51
# 1018959                                UNION GROVE VILLAGE          38
# 1274396                           Southern Fidelity Ins Co          60
# 2329733                                     AAA INSURANCE           76
# 139664                              Bank of Travelers Rest          32
# 170152                                  Quicken Loans, Inc          58
# 3189956              Great American E&S Insurance Company           73
# 1445791                                   ERIE INSURANCE            63
# 2151271                                     MCHENRY COUNTY          75
# 3106783                                 GERMANIA INS GROUP          59
# 1567930                                  WESBANCO BANK INC          46
# 2114956                                     HIGHLANDS TOWN          56
# 1344616                      AIG Property Casualty Company          62
# 2517956                              SOUTH ORANGE TOWNSHIP          52
# 72638                                GUARDIAN CREDIT UNION         100
# 4758555                                      PLANTERS BANK          50
# 3505984                                             CP FCU          77
# 4617034  Metropolitan Property & Casualty Insurance Com...          75
# 4600163                            BANKERS INSURANCE GROUP          74
# 4692133                               PEOPLES TRUST INC CO          50
#
#          similarity_token_sort_ratio
# 1202384                           56
# 1018959                           65
# 1274396                           60
# 2329733                           79
# 139664                            59
# 170152                            45
# 3189956                           64
# 1445791                           67
# 2151271                           75
# 3106783                           54
# 1567930                           56
# 2114956                           51
# 1344616                           53
# 2517956                           57
# 72638                            100
# 4758555                           56
# 3505984                           46
# 4617034                           72
# 4600163                           70
# 4692133                           60

# %% [markdown]
# ### Match names Quicken vs Arcus with KNeighbors

# %%
clean_org_names = dataset_client
org_name_clean = dataset.name

# %%
print("=====================  Match names Arcus vs Quicken with KNeighbors")
t1 = time.time()
unique_org = dataset_payees
for i in ANALIZERS:
    distances, indices = train_vectorize(org_name_clean, unique_org, analyzer=i)
    unique_org = payees.name
    matches = matches + find_matches(matches,indices, distances, org_name_clean, unique_org, invert= False)
print("=====================  COMPLETED IN:", t)
# Out:
# =====================  Match names Arcus vs Quicken with KNeighbors
# =====================================================Vecorizing the data - this could take a few minutes for large datasets... =====================================================
# =====================  COMPLETED IN: 0.3317091464996338
# =====================  Vecorizing completed...
# =====================  finding matches...
# =====================  COMPLETED IN: 19.245259046554565
# =====================================================Vecorizing the data - this could take a few minutes for large datasets... =====================================================
# =====================  COMPLETED IN: 0.3798818588256836
# =====================  Vecorizing completed...
# =====================  finding matches...
# =====================  COMPLETED IN: 18.37052607536316
# =====================================================Vecorizing the data - this could take a few minutes for large datasets... =====================================================
# =====================  COMPLETED IN: 0.7399969100952148
# =====================  Vecorizing completed...
# =====================  finding matches...
# =====================  COMPLETED IN: 16.554336071014404
# =====================================================Vecorizing the data - this could take a few minutes for large datasets... =====================================================
# =====================  COMPLETED IN: 2.0616328716278076
# =====================  Vecorizing completed...
# =====================  finding matches...
# =====================  COMPLETED IN: 17.14095115661621
# =====================  COMPLETED IN: 174.2350480556488

# %%
print('Building data frame...')  
matches_df = pd.DataFrame(matches, columns=['match confidence(knn)','Arcus name','Quicken name', 'similarity', 'similarity_token_sort_ratio'])
print('Done')
# Out:
# Building data frame...
# Done

# %%
matches_df.sample(20, random_state=42)
# Out:
#           match confidence(knn)                              Arcus name  \
# 162432                     0.31  Seattle Metropolitan Credit Union Loan
# 136651                     0.33             Loyal American Insurance Co
# 169250                     0.48                    Edison Tax Collector
# 1080006                    0.90                       Old National Bank
# 1176894                    0.59                       Rural Mutual Ins.
# 83917                      0.43       Freedom Federal Credit Union Loan
# 1203566                    1.09           Wolverine Mutual Insurance Co
# 5088726                    0.45        Turnstone Homeowners Association
# 1087781                    1.16        Community Financial Services FCU
# 96593                      0.35        Scient Federal Credit Union Loan
# 5052025                    0.48                            City of Napa
# 1101493                    1.10     American National Insurance Company
# 5061069                    0.45                    The City of Neodesha
# 1079992                    1.04            Travelers Personal Insurance
# 1118499                    1.01                          Cambridge CVTY
# 107604                     0.46    National Indemnity Insurance Company
# 20832509                   1.03     Terrace View Homeowners Association
# 1157180                    0.57                 Credit Union of America
# 1191415                    1.15             United of Omaha Life Ins Co
# 20852436                   1.09                    Mid Rivers Telephone
#
#                                      Quicken name  similarity  \
# 162432                ATLANTA POSTAL CREDIT UNION          65
# 136651                  Central Insurance Company          62
# 169250                 MELBA KREADY TAX COLLECTOR          70
# 1080006                      NATIONAL FINANCE 120          59
# 1176894               WAWANESA MUTUAL INS COMPANY          55
# 83917                        WELCOME FEDERAL CRED          60
# 1203566                 Amica MUTUAL INSURANCE CO          78
# 5088726     TEXAS WINDSTORM INSURANCE ASSOCIATION          58
# 1087781                      NASSAU FINANCIAL FCU          58
# 96593                      Heartland Credit Union          59
# 5052025                            CITY OF ALBANY          77
# 1101493                   INTEGON NATIONAL INS CO          62
# 5061069         HOMESITE INSURANCE OF THE MIDWEST          45
# 1079992                   Travelers Home & Marine          59
# 1118499                        CAMBRIDGE TOWNSHIP          69
# 107604                        COMMUNITY FINANCIAL          47
# 20832509  Homeowners of America Insurance Company          46
# 1157180                      BANK OF AMERICA N.A.          56
# 1191415                    MIDSTATE MUTUAL INS CO          57
# 20852436                     HORRY TELEPHONE COOP          60
#
#           similarity_token_sort_ratio
# 162432                             55
# 136651                             62
# 169250                             70
# 1080006                            59
# 1176894                            56
# 83917                              60
# 1203566                            70
# 5088726                            58
# 1087781                            62
# 96593                              67
# 5052025                            54
# 1101493                            59
# 5061069                            57
# 1079992                            57
# 1118499                            69
# 107604                             62
# 20832509                           59
# 1157180                            52
# 1191415                            53
# 20852436                           65

# %% [markdown]
# ### Match names Quicken vs Arcus with KNeighbors

# %%
matches_df = matches_df.drop_duplicates(subset=['Arcus name', 'Quicken name'])
matches_df.shape
# Out:
# (417500, 5)

# %%
matches_df[matches_df['similarity_token_sort_ratio'] > 65]
# Out:
#           match confidence(knn)                              Arcus name  \
# 0                          0.31                             Capital One
# 2                          0.45                            Old West FCU
# 18                         0.36                   Brauns Capital One RS
# 43                         0.00                  Barclays Bank Delaware
# 47                         0.49            Barclays Bank Consumer Loans
# ...                         ...                                     ...
# 41740483                   0.97  Water And Power Community Credit Union
# 41740485                   0.99  Water And Power Community Credit Union
# 41740502                   0.97    Westerly Community Credit Union Loan
# 41740509                   1.00              Winslow Community FCU Loan
# 41740510                   0.89           Wright Patt Credit Union Loan
#
#                             Quicken name  similarity  \
# 0                             CapitalOne          95
# 2                         Goldenwest FCU          85
# 18                CAPITAL ONE BANK USA N          60
# 43                BARCLAYS BANK DELAWARE         100
# 47                BARCLAYS BANK DELAWARE          68
# ...                                  ...         ...
# 41740483            OUR COMMUNITY CREDIT          66
# 41740485  U of VA Community Credit Union          74
# 41740502    HAPO COMMUNITY CREDIT UNION           75
# 41740509              UTAH COMMUNITY FCU          64
# 41740510          CREDIT UNION LOAN SOUR          67
#
#           similarity_token_sort_ratio
# 0                                  95
# 2                                  85
# 18                                 79
# 43                                100
# 47                                 68
# ...                               ...
# 41740483                           69
# 41740485                           76
# 41740502                           76
# 41740509                           68
# 41740510                           71
#
# [113542 rows x 5 columns]

# %%
capital_one =  matches_df[matches_df['Quicken name'] == 'CAPITAL ONE BANK USA N']
capital_one[capital_one['similarity_token_sort_ratio'] > 90]
capital_one.sort_values('similarity_token_sort_ratio', ascending=False)
# Out:
#          match confidence(knn)                Arcus name  \
# 18                        0.36     Brauns Capital One RS
# 5121382                   0.41      Amana Capital One RS
# 5121667                   0.44     BNB RS CAPITAL ONE RS
# 1072771                   1.06       BJ's Capital One RS
# 1072759                   0.97           Capital One, NA
# ...                        ...                       ...
# 359135                    0.50    Pinnacle Bank Nebraska
# 17                        0.35  American State Bank Loan
# 5063917                   0.46            ACNB Bank Loan
# 5126334                   0.43      Associated Bank Loan
# 5021645                   0.44               Alpine Bank
#
#                    Quicken name  similarity  similarity_token_sort_ratio
# 18       CAPITAL ONE BANK USA N          60                           79
# 5121382  CAPITAL ONE BANK USA N          62                           76
# 5121667  CAPITAL ONE BANK USA N          60                           74
# 1072771  CAPITAL ONE BANK USA N          63                           73
# 1072759  CAPITAL ONE BANK USA N          76                           72
# ...                         ...         ...                          ...
# 359135   CAPITAL ONE BANK USA N          59                           50
# 17       CAPITAL ONE BANK USA N          57                           48
# 5063917  CAPITAL ONE BANK USA N          56                           44
# 5126334  CAPITAL ONE BANK USA N          57                           43
# 5021645  CAPITAL ONE BANK USA N          61                           42
#
# [88 rows x 5 columns]

# %%
capital_one = matches_df[matches_df['Quicken name'] == 'CAPITAL ONE']
capital_one[capital_one['similarity_token_sort_ratio'] > 85]
capital_one.sort_values('similarity_token_sort_ratio', ascending=False).drop_duplicates(subset=['Arcus name', 'Quicken name'])
# Out:
#           match confidence(knn)                     Arcus name Quicken name  \
# 345                        0.00                    Capital One  CAPITAL ONE
# 1073117                    0.75                Capital One, NA  CAPITAL ONE
# 20854479                   0.78                     Carpet One  CAPITAL ONE
# 20854155                   0.87             BDP CAPITAL ONE RS  CAPITAL ONE
# 1073141                    0.92            Bose Capital One RS  CAPITAL ONE
# 1073136                    0.92            Sony Capital One RS  CAPITAL ONE
# 1073127                    0.90            BJ's Capital One RS  CAPITAL ONE
# 1073119                    0.82            York Capital One RS  CAPITAL ONE
# 1073118                    0.80            VISA CAPITAL ONE RS  CAPITAL ONE
# 1073137                    0.92            UBID CAPITAL ONE RS  CAPITAL ONE
# 350                        0.41           Marlo Capital One RS  CAPITAL ONE
# 348                        0.39           Amana Capital One RS  CAPITAL ONE
# 1073122                    0.88           Sears Capital One RS  CAPITAL ONE
# 20854272                   1.12          BNB RS CAPITAL ONE RS  CAPITAL ONE
# 1073145                    0.92          Brauns Capital One RS  CAPITAL ONE
# 1073128                    0.91          Yamaha Capital One RS  CAPITAL ONE
# 1073132                    0.91         Carrier Capital One RS  CAPITAL ONE
# 20854112                   1.04         Art Van Capital One RS  CAPITAL ONE
# 20854626                   1.14         Comp RS Capital One RS  CAPITAL ONE
# 1073148                    0.92         Gemaire Capital One RS  CAPITAL ONE
# 1073142                    0.92         Bowflex Capital One RS  CAPITAL ONE
# 1073139                    0.92         Menards Capital One RS  CAPITAL ONE
# 347                        0.38         Polaris Capital One RS  CAPITAL ONE
# 1073143                    0.92         Webergs Capital One RS  CAPITAL ONE
# 1073131                    0.91         Payless Capital One RS  CAPITAL ONE
# 20855926                   1.06         Sam Ash Capital One RS  CAPITAL ONE
# 1073121                    0.85         Gateway Capital One RS  CAPITAL ONE
# 1073146                    0.92        Bradlees Capital One RS  CAPITAL ONE
# 1073120                    0.83        Jordan's Capital One RS  CAPITAL ONE
# 20854361                   0.87        Breuners Capital One RS  CAPITAL ONE
# 1073130                    0.91        Kawasaki Capital One RS  CAPITAL ONE
# 351                        0.41       Ortholine Capital One RS  CAPITAL ONE
# 1073126                    0.90      Polaris Capital One RS -1  CAPITAL ONE
# 1073140                    0.92       Intercity Capital One RS  CAPITAL ONE
# 346                        0.33       Capital One Auto Finance  CAPITAL ONE
# 20855047                   1.00       Good Guys Capital One RS  CAPITAL ONE
# 1073113                    0.60      Capital One Card Services  CAPITAL ONE
# 20855892                   0.92     Rhodes Inc. Capital One RS  CAPITAL ONE
# 1073123                    0.89      Mitsubishi Capital One RS  CAPITAL ONE
# 1073129                    0.91      Electrolux Capital One RS  CAPITAL ONE
# 349                        0.40     Capital One Corporate Card  CAPITAL ONE
# 1073134                    0.92     Gottschalks Capital One RS  CAPITAL ONE
# 1073147                    0.92     Facelifters Capital One RS  CAPITAL ONE
# 1073116                    0.74    Capital One Retail Services  CAPITAL ONE
# 5075216                    0.46           Capitola Del Mar HOA  CAPITAL ONE
# 1073144                    0.92    Beachcombers Capital One RS  CAPITAL ONE
# 352                        0.43              Camp Capitola HOA  CAPITAL ONE
# 20854914                   1.04   Furniture Row Capital One RS  CAPITAL ONE
# 20855031                   1.00   GM Goodwrench Capital One RS  CAPITAL ONE
# 20855088                   1.04   Guitar Center Capital One RS  CAPITAL ONE
# 20855648                   1.07   Neiman Marcus Capital One RS  CAPITAL ONE
# 20855688                   0.96   Northern Tool Capital One RS  CAPITAL ONE
# 1073124                    0.90  Capital One Credit Card Serv.  CAPITAL ONE
# 41739068                   0.00   Gardner White Capital One RS  CAPITAL ONE
#
#           similarity  similarity_token_sort_ratio
# 345              100                          100
# 1073117           85                           88
# 20854479          76                           76
# 20854155          76                           76
# 1073141           73                           73
# 1073136           73                           73
# 1073127           73                           73
# 1073119           73                           73
# 1073118           73                           73
# 1073137           73                           73
# 350               71                           71
# 348               71                           71
# 1073122           71                           71
# 20854272          69                           69
# 1073145           69                           69
# 1073128           69                           69
# 1073132           67                           67
# 20854112          67                           67
# 20854626          67                           67
# 1073148           67                           67
# 1073142           67                           67
# 1073139           67                           67
# 347               67                           67
# 1073143           67                           67
# 1073131           67                           67
# 20855926          67                           67
# 1073121           67                           67
# 1073146           65                           65
# 1073120           65                           65
# 20854361          65                           65
# 1073130           65                           65
# 351               63                           63
# 1073126           61                           63
# 1073140           63                           63
# 346               63                           63
# 20855047          63                           63
# 1073113           61                           61
# 20855892          59                           61
# 1073123           61                           61
# 1073129           61                           61
# 349               59                           59
# 1073134           59                           59
# 1073147           59                           59
# 1073116           58                           58
# 5075216           58                           58
# 1073144           58                           58
# 352               57                           57
# 20854914          56                           56
# 20855031          56                           56
# 20855088          56                           56
# 20855648          56                           56
# 20855688          56                           56
# 1073124           55                           56
# 41739068          56                           56

# %%
matches_df[matches_df['Quicken name'] == 'BARCLAYS BANK DELAWA']
# Out:
#          match confidence(knn)                    Arcus name  \
# 1478                      0.14        Barclays Bank Delaware
# 1479                      0.39             The Callaway Bank
# 1480                      0.42       Baldwin State Bank Loan
# 1481                      0.45      Brady National Bank Loan
# 1482                      0.48              Badger Bank Loan
# 1483                      0.49  Barclays Bank Consumer Loans
# 1484                      0.49                Abby Bank Loan
# 1485                      0.49                Dart Bank Loan
# 1486                      0.50              Legacy Bank Loan
# 1487                      0.51                Heartland Bank
# 1488                      0.52                ACNB Bank Loan
# 1489                      0.52            Citywide bank loan
# 1490                      0.53            Seacoast Bank Loan
# 1491                      0.53               Wells Bank Loan
# 360577                    0.63           Blackhawk Bank Loan
# 1074284                   0.85        Barclays Benefits-1329
# 1074285                   0.85        Barclays Benefits-1330
#
#                  Quicken name  similarity  similarity_token_sort_ratio
# 1478     BARCLAYS BANK DELAWA          95                           95
# 1479     BARCLAYS BANK DELAWA          49                           59
# 1128165   Bank of America          57                           57
# 1128166   Bank of America          47                           67
# 1128167   Bank of America          45                           65
# 1128171   Bank of America          56                           65
# 1128173   Bank of America          62                           62
# 1128174   Bank of America          58                           54
# 1128175   Bank of America          51                           65
# 2497418   Bank of America          58                           58
# 5022569   Bank of America          32                           56
# 5022858   Bank of America          69                           44
# 5126465   Bank of America          61                           62
# 5126501   Bank of America          61                           62
# 5126620   Bank of America          62                           62
# 20801923  Bank of America          61                           48
# 20806974  Bank of America          69                           63
# 20838414  Bank of America          60                           60
# 20847875  Bank of America          58                           63
# 20850913  Bank of America          60                           60
# 20856141  Bank of America          63                           67
# 20856318  Bank of America          62                           56
# 20856371  Bank of America          50                           56
# 20856410  Bank of America          53                           59
# 41739592  Bank of America          60                           61

# %%
bank = matches_df[matches_df['Quicken name'] == 'BANK OF AMER']
bank.sort_values(by=['similarity_token_sort_ratio'], ascending=False)
# Out:
#          match confidence(knn)                       Arcus name  Quicken name  \
# 16925                     0.38            Bank of America - AFS  BANK OF AMER
# 16930                     0.42              First American Bank  BANK OF AMER
# 375724                    0.58         Bank of America Mortgage  BANK OF AMER
# 16924                     0.37            Bank of Commerce Loan  BANK OF AMER
# 16931                     0.43               Bank of Early Loan  BANK OF AMER
# 16935                     0.45                     Bank of Utah  BANK OF AMER
# 5073864                   0.49                 Bean Creek H.O.A  BANK OF AMER
# 16928                     0.41   Bank of America Line of Credit  BANK OF AMER
# 1090115                   0.76                    New Amer Fund  BANK OF AMER
# 16934                     0.45  American Bank of the North Loan  BANK OF AMER
# 16926                     0.39                 Bank of Commerce  BANK OF AMER
# 375722                    0.58                Bank of Millbrook  BANK OF AMER
# 16929                     0.41                Bank of Oak Ridge  BANK OF AMER
# 16933                     0.44          Bank of New Madrid Loan  BANK OF AMER
# 375720                    0.55          Bank of Brookhaven Loan  BANK OF AMER
# 5126795                   0.51          Bank Of New Mexico Loan  BANK OF AMER
# 16927                     0.40              First Bank of Berne  BANK OF AMER
# 16932                     0.43         Bank of The Prairie Loan  BANK OF AMER
# 5112326                   0.64                        Box Maker  BANK OF AMER
#
#          similarity  similarity_token_sort_ratio
# 16925            73                           77
# 16930            39                           71
# 375724           67                           67
# 16924            67                           61
# 16931            67                           60
# 16935            75                           58
# 5073864          50                           57
# 16928            57                           57
# 1090115          48                           56
# 16934            47                           56
# 16926            79                           50
# 375722           69                           48
# 16929            69                           48
# 16933            57                           46
# 375720           57                           46
# 5126795          57                           46
# 16927            65                           45
# 16932            56                           39
# 5112326          57                           29

# %%
amica_mutual = matches_df[matches_df['Arcus name'] == 'Amica Mutual Insurance Company']
amica_mutual.sort_values(by='similarity_token_sort_ratio', ascending=False)
# Out:
#          match confidence(knn)                      Arcus name  \
# 143783                    0.00  Amica Mutual Insurance Company
# 175302                    0.00  Amica Mutual Insurance Company
# 38721                     0.00  Amica Mutual Insurance Company
# 44697                     0.25  Amica Mutual Insurance Company
# 161722                    0.25  Amica Mutual Insurance Company
# ...                        ...                             ...
# 119405                    0.42  Amica Mutual Insurance Company
# 138638                    0.39  Amica Mutual Insurance Company
# 51703                     0.48  Amica Mutual Insurance Company
# 125017                    0.46  Amica Mutual Insurance Company
# 2495962                   0.96  Amica Mutual Insurance Company
#
#                                Quicken name  similarity  \
# 143783       Amica Mutual INsurance Company         100
# 175302       AMICA MUTUAL INSURANCE COMPANY         100
# 38721        Amica Mutual Insurance Company         100
# 44697         Alfa Mutual Insurance Company          92
# 161722        ALFA MUTUAL INSURANCE COMPANY          92
# ...                                     ...         ...
# 119405                 MUNICIPAL MUTUAL INS          60
# 138638    MUSCATINE MUTUAL INS ASS OCIATION          60
# 51703                WAWANESA MUTUAL INS CO          62
# 125017       Farm Bureau Casualty Insurance          57
# 2495962  WINDSOR-MOUNT JOY MUTUAL INSURANCE          56
#
#          similarity_token_sort_ratio
# 143783                           100
# 175302                           100
# 38721                            100
# 44697                             92
# 161722                            92
# ...                              ...
# 119405                            52
# 138638                            51
# 51703                             50
# 125017                            50
# 2495962                           50
#
# [326 rows x 5 columns]

# %%
matches_df[matches_df['Quicken name'] == 'Partners Federal CU']
# Out:
#          match confidence(knn)                            Arcus name  \
# 106944                    0.31         Partners Federal Credit Union
# 106945                    0.38            Apple Federal Credit Union
# 106946                    0.38         Star USA Federal Credit Union
# 106947                    0.38         Realtors Federal Credit Union
# 106948                    0.38              APL Federal Credit Union
# 106949                    0.40           Strata Federal Credit Union
# 106950                    0.40            Altra Federal Credit Union
# 106951                    0.40          Fortera Federal Credit Union
# 106952                    0.41               CP Federal Credit Union
# 106953                    0.41  Harvesters Federal Credit Union Loan
# 106954                    0.41          Rutgers Federal Credit Union
# 106955                    0.42                   Pentagon Federal CU
# 106956                    0.42              SAC Federal Credit Union
# 106957                    0.42                Worcester Fire Dept CU
# 106958                    0.42     Great Lakes First Federal Cu Loan
# 106959                    0.43                      First Federal CU
# 106960                    0.43         Accentra Federal Credit Union
# 106961                    0.43        Air Force Federal Credit Union
# 106962                    0.43            Tulsa Federal Credit Union
# 106963                    0.43           Pheple Federal Credit Union
# 106964                    0.43              CPM Federal Credit Union
# 106965                    0.43    Greater Metro Federal Credit Union
# 106966                    0.43              ESL Federal Credit Union
# 106967                    0.44   Penn East Federal Credit Union Loan
# 1177018                   0.76                    Financial Partners
# 1177019                   0.89                Financial Partners FCU
# 1177021                   0.98                       BLUE FEDERAL CU
# 1177022                   1.01                       Campus Partners
# 1177023                   1.04             Legacy Community Partners
# 1177024                   1.06                       XCEL Federal Cu
# 1177025                   1.07                      LTC Partners LLC
# 1177026                   1.07            Nationwide Energy Partners
# 1177027                   1.08                        HFS Federal CU
# 1177029                   1.09       Chesapeake Capital Partners LLC
# 5028458                   0.49          Federal Employees Newark FCU
#
#                 Quicken name  similarity  similarity_token_sort_ratio
# 106944   Partners Federal CU          79                           75
# 106945   Partners Federal CU          58                           49
# 106946   Partners Federal CU          58                           58
# 106947   Partners Federal CU          62                           58
# 106948   Partners Federal CU          56                           51
# 106949   Partners Federal CU          57                           57
# 106950   Partners Federal CU          62                           49
# 106951   Partners Federal CU          64                           60
# 106952   Partners Federal CU          57                           52
# 106953   Partners Federal CU          62                           58
# 106954   Partners Federal CU          68                           64
# 106955   Partners Federal CU          74                           74
# 106956   Partners Federal CU          56                           56
# 106957   Partners Federal CU          59                           54
# 106958   Partners Federal CU          62                           58
# 106959   Partners Federal CU          74                           74
# 106960   Partners Federal CU          58                           46
# 106961   Partners Federal CU          57                           49
# 106962   Partners Federal CU          58                           53
# 106963   Partners Federal CU          57                           52
# 106964   Partners Federal CU          56                           51
# 106965   Partners Federal CU          57                           53
# 106966   Partners Federal CU          60                           51
# 106967   Partners Federal CU          56                           48
# 1177018  Partners Federal CU          43                           65
# 1177019  Partners Federal CU          59                           73
# 1177021  Partners Federal CU          71                           59
# 1177022  Partners Federal CU          47                           65
# 1177023  Partners Federal CU          36                           64
# 1177024  Partners Federal CU          71                           71
# 1177025  Partners Federal CU          63                           69
# 1177026  Partners Federal CU          40                           58
# 1177027  Partners Federal CU          73                           73
# 1177029  Partners Federal CU          44                           60
# 5028458  Partners Federal CU          43                           60

# %%
len(matches_df['Quicken name'].unique())
# Out:
# 19341

# %%
len(matches_df['Quicken name'])
# Out:
# 417500

# %%
len(matches_df['Arcus name'].unique())
# Out:
# 14933

# %%
len(matches_df['Arcus name'])
# Out:
# 417500

# %%
result = payees.merge(matches_df, left_on='name', right_on='Arcus name', how='inner')

# %%
amica_mutual = result[result['Arcus name'] == 'Amica Mutual Insurance Company']
amica_mutual.sort_values(by='similarity_token_sort_ratio', ascending=False)
# Out:
#          Category                            name  match confidence(knn)  \
# 216840  Insurance  Amica Mutual Insurance Company                   0.00
# 216896  Insurance  Amica Mutual Insurance Company                   0.00
# 216678  Insurance  Amica Mutual Insurance Company                   0.00
# 216686  Insurance  Amica Mutual Insurance Company                   0.25
# 216872  Insurance  Amica Mutual Insurance Company                   0.25
# ...           ...                             ...                    ...
# 216806  Insurance  Amica Mutual Insurance Company                   0.42
# 216833  Insurance  Amica Mutual Insurance Company                   0.39
# 216699  Insurance  Amica Mutual Insurance Company                   0.48
# 216814  Insurance  Amica Mutual Insurance Company                   0.46
# 216938  Insurance  Amica Mutual Insurance Company                   0.96
#
#                             Arcus name                        Quicken name  \
# 216840  Amica Mutual Insurance Company      Amica Mutual INsurance Company
# 216896  Amica Mutual Insurance Company      AMICA MUTUAL INSURANCE COMPANY
# 216678  Amica Mutual Insurance Company      Amica Mutual Insurance Company
# 216686  Amica Mutual Insurance Company       Alfa Mutual Insurance Company
# 216872  Amica Mutual Insurance Company       ALFA MUTUAL INSURANCE COMPANY
# ...                                ...                                 ...
# 216806  Amica Mutual Insurance Company                MUNICIPAL MUTUAL INS
# 216833  Amica Mutual Insurance Company   MUSCATINE MUTUAL INS ASS OCIATION
# 216699  Amica Mutual Insurance Company              WAWANESA MUTUAL INS CO
# 216814  Amica Mutual Insurance Company      Farm Bureau Casualty Insurance
# 216938  Amica Mutual Insurance Company  WINDSOR-MOUNT JOY MUTUAL INSURANCE
#
#         similarity  similarity_token_sort_ratio
# 216840         100                          100
# 216896         100                          100
# 216678         100                          100
# 216686          92                           92
# 216872          92                           92
# ...            ...                          ...
# 216806          60                           52
# 216833          60                           51
# 216699          62                           50
# 216814          57                           50
# 216938          56                           50
#
# [326 rows x 7 columns]

# %%
print(len(matches_df['Quicken name'].unique()), ' quicken unique')
print(len(matches_df['Arcus name'].unique()), ' arcus unique')
print(matches_df.shape, ' all data')
# Out:
# 19341  quicken unique
# 14933  arcus unique
# (417500, 5)  all data

# %%
print(len(matches_df['Quicken name'].unique()), ' quicken unique')
print(len(matches_df['Arcus name'].unique()), ' arcus unique')
print(matches_df.shape, ' all data')
# Out:
# 19341  quicken unique
# 14933  arcus unique
# (417500, 5)  all data

# %%
sim_m_75 = matches_df[matches_df['similarity'] > 60]

# %%
len(sim_m_75['Quicken name'].unique())
# Out:
# 16139

# %%
sim_a_75 = matches_df[(matches_df['match confidence(knn)'] < 1) & (matches_df['match confidence(knn)'] > 0 )]

# %%
sim_a_75.sort_values(by=['match confidence(knn)', 'similarity'], ascending=True)
# Out:
#          match confidence(knn)                                  Arcus name  \
# 70474                     0.07  New Jersey Manufacturers Insurance Company
# 143165                    0.07     Michigan Basic Property Insurance Assoc
# 137424                    0.08               Indiana Farm Bureau Insurance
# 154770                    0.08                   Xcel Federal Credit Union
# 175188                    0.08               Universal Property & Casualty
# ...                        ...                                         ...
# 1173545                   0.99                       Harris County MUD 188
# 1173546                   0.99                       Harris County MUD 127
# 1173547                   0.99                       Harris County MUD 261
# 1173549                   0.99                       Harris County MUD 162
# 2491993                   0.99                   WSSC Federal Credit Union
#
#                                       Quicken name  similarity  \
# 70474    NEW JERSEY MANUFACTURES INSURANCE COMPANY          99
# 143165      Michigan Basic Property Insurance ASSc          99
# 137424                Indian Farm Bureau Insurance          98
# 154770                  EXCEL Federal Credit Union          98
# 175188                Universal Property & Casualy          98
# ...                                            ...         ...
# 1173545                      HARRIS COUNTY MUD 153          90
# 1173546                      HARRIS COUNTY MUD 153          90
# 1173547                      HARRIS COUNTY MUD 153          90
# 1173549                      HARRIS COUNTY MUD 153          90
# 2491993                   SRP Federal Credit Union          90
#
#          similarity_token_sort_ratio
# 70474                             99
# 143165                            99
# 137424                            98
# 154770                            78
# 175188                            98
# ...                              ...
# 1173545                           90
# 1173546                           90
# 1173547                           90
# 1173549                           90
# 2491993                           82
#
# [313926 rows x 5 columns]

# %%
matches_df.to_excel("matched_names_tf_idf.xlsx", engine="xlsxwriter", index=False)
matches_df.to_csv("matched_names_tf_idf.csv", index=False)

# %%
matches_df.shape
# Out:
# (417500, 5)

# %%
print(len(matches_df['Quicken name'].unique()), ' quicken unique')
print(len(matches_df['Arcus name'].unique()), ' arcus unique')
print(matches_df.shape, ' all data')
# Out:
# 19341  quicken unique
# 14933  arcus unique
# (417500, 5)  all data

# %%
nNames = len(matches_df['Quicken name'].unique())
print("Total dataset", dataset_client.shape[0])
print("Total Names found ", nNames)
print("Percent : ", 100 * nNames / dataset_client.shape[0], '%')
# Out:
# Total dataset 21109
# Total Names found  19341
# Percent :  91.62442560045479 %
